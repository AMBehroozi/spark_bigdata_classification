# %%
import requests
import zipfile
import io
import os

# --- CONFIGURATION: CHANGE THIS PATH TO WHERE YOU WANT TO SAVE ---
# Example: "/home/mehdi/Documents/SQL/American_Express/datasets/amex-raddar-parquet"
SAVE_PATH = "data/amex-raddar-parquet" 
# -----------------------------------------------------------------

url = "https://storage.googleapis.com/kaggle-data-sets/2291599/3852083/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20251124%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20251124T215824Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

print(f"Preparing to download to: {SAVE_PATH}")

# 1. Create the directory if it doesn't exist
if not os.path.exists(SAVE_PATH):
    print(f"Creating directory: {SAVE_PATH}")
    os.makedirs(SAVE_PATH, exist_ok=True)

# 2. Download
print("Downloading file... (This may take a moment)")
r = requests.get(url, stream=True)

if r.status_code == 200:
    print("Download complete. Unzipping...")
    
    # 3. Unzip directly from memory to the specific SAVE_PATH
    try:
        z = zipfile.ZipFile(io.BytesIO(r.content))
        z.extractall(SAVE_PATH)
        print(f"✅ Success! Data extracted to: {os.path.abspath(SAVE_PATH)}")
    except zipfile.BadZipFile:
        print("❌ Error: The downloaded file is not a valid zip file. The link might have expired.")
else:
    print(f"❌ Failed to download. Status code: {r.status_code}")
# Out:
# Preparing to download to: /storage/group/cxs1024/default/mehdi/data/amex-raddar-parquet
# Creating directory: /storage/group/cxs1024/default/mehdi/data/amex-raddar-parquet
# ...
# Download complete. Unzipping...
# ✅ Success! Data extracted to: /storage/group/cxs1024/default/mehdi/data/amex-raddar-parquet
